# %% [markdown]
# <a href="https://colab.research.google.com/github/Mridini31/Internship-IITG/blob/main/Review_paper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data from your table
years = [2000, 2005, 2010, 2015, 2020, 2024]
values = [5, 14, 13, 24, 27, 33]

# Plotting
plt.figure(figsize=(8,5))
plt.plot(years, values, marker='o', color='blue')

# Labels and title
plt.xlabel('Year')
plt.ylabel('Number of Papers')
plt.title('Biomedical Research')

# Grid and display
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from your table
years = [2000, 2005, 2010, 2015, 2020, 2024]
values = [0, 13, 14, 25, 127, 218]

# Plotting
plt.figure(figsize=(8,5))
plt.plot(years, values, marker='o', color='blue')

# Labels and title
plt.xlabel('Year')
plt.ylabel('Number of Papers')
plt.title('Anomaly Detection')

# Grid and display
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from your table
years = [2000, 2005, 2010, 2015, 2020, 2024]
values = [1, 0, 2, 3, 6, 33]

# Plotting
plt.figure(figsize=(8,5))
plt.plot(years, values, marker='o', color='blue')

# Labels and title
plt.xlabel('Year')
plt.ylabel('Number of Papers')
plt.title('Finance')

# Grid and display
plt.grid(True)
plt.show()
